# %% [markdown]
# ### Langchain Version V1

# %%
import langchain
print(langchain.__version__)

# %%
import os
from dotenv import load_dotenv

load_dotenv()

print(os.getenv("GROQ_API_KEY"))

# %% [markdown]
# Generative AI Applications using Agents And Groq Model

# %%
from dotenv import load_dotenv
import os

load_dotenv(dotenv_path=".env")
print(os.getenv("GROQ_API_KEY"))

# %%
import os
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model

load_dotenv()

print(os.getenv("GROQ_API_KEY"))  # debug

model = init_chat_model("groq:llama-3.1-8b-instant")

response = model.invoke("write me a joke on machine learning algorithms")
print(response.content)

# %% [markdown]
# ### Reasoning Model

# %%
import os
from langchain_groq import ChatGroq

model = ChatGroq(model="qwen/qwen3-32b")
response = model.invoke("why do parrots talk?")
response

# %%
response.content

# %% [markdown]
# ### Streaming and Batch
#
# streaming
#
# Most models can stream their output content while it is being generated. By displaying output progressively, streaming significantly improves user experience, particularly for longer responses. Calling stream() returns an iterator that yields output chunks as they are produced. You can use a loop to process each chunk in real-time:

# %%
model.invoke("Write me a 500 words paragraph on Indian Railways")

# %%
model.stream("Write me a 500 words paragraph on Indian Railways")

# %%
for chunk in model.stream("Write me a 500 words paragraph on Indian Railways"):
    print(chunk.text,end="",flush=True)

# %% [markdown]
# ### Batch
#
# Batching a collection of independent requests to a model can significantly improve performance and reduce costs,as the processing can be done in parallel:

# %%
response = model.batch([
    "List the fastest Trains of India?",
    "How do airplanes fly?",
    "what is quantum computing?"
])

for res in response:
    print(res.content)

# %%
model.batch([
    "List the fastest Trains of India?",
    "How do airplanes fly?",
    "what is quantum computing?"],
    config={
        'max_concurrency': 5, # Limit to 5 parallel  calls
    }
    
    )
